# %%
import numpy as np

# %%
np.random.randint(1,100000)
# Out:
# 34604

# %%
k=[{1: {"a": 1, "b": 2, "c": 3}}, {2: {"d": 4, "e": 5, "f": 6}}]

# %%
k[0][1]
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
import hashlib

# %%
obj=hashlib.sha256()

# %%
obj.update(b'hello')

# %%
print(obj.hexdigest())
# Out:
# 2cf24dba5fb0a30e26e83b2ac5b9e29e1b161e5c1fa7425e73043362938b9824

# %%
k=[{"ELE45786": {"id": "ELE45786", "Elector's_name": "Vinod", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE45693": {"id": "ELE45693", "Elector's_name": "Mani", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE45201": {"id": "ELE45201", "Elector's_name": "Ratnam", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE45101": {"id": "ELE45101", "Elector's_name": "John", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE45999":{"id": "ELE45999", "Elector's_name": "Alladin", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE45789": {"id": "ELE45789", "Elector's_name": "Ram Ratna", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE46790": {"id": "ELE46790", "Elector's_name": "Teelu", "DOB": 1995, "voted": 0, "party": None}}]

# %%
k[0]['ELE45786']['voted']=1
k
# Out:
# [{'ELE45786': {'id': 'ELE45786',
#    "Elector's_name": 'Vinod',
#    'DOB': 1995,
#    'voted': 1,
#    'party': None}},
#  {'ELE45693': {'id': 'ELE45693',
#    "Elector's_name": 'Mani',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE45201': {'id': 'ELE45201',
#    "Elector's_name": 'Ratnam',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE45101': {'id': 'ELE45101',
#    "Elector's_name": 'John',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE45999': {'id': 'ELE45999',
#    "Elector's_name": 'Alladin',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE45789': {'id': 'ELE45789',
#    "Elector's_name": 'Ram Ratna',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE46790': {'id': 'ELE46790',
#    "Elector's_name": 'Teelu',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}}]

# %%
for char in k:
    print(K[k.index(char)][])
# Out:
#   Cell In[1], line 2
#     print(K[k.index(char)][])
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
for char in l:
    print(char)
# Out:
# 1
# 2
# 3
# 45

# %%
a=['c','m','x']

# %%
for char in a:
    if a=="c" or "m" or "x":
        print('ok')
# Out:
# ok
# ok
# ok

# %%
class input:
    def req(self):
        self.input=input("Enter text field:")
        return self.input

# %%
l=[1,2,3,45]

# %%
for char in l:
    print(char)
# Out:
# 1
# 2
# 3
# 45

# %%
    def voter_list():
        '''We do not have a database so we are considering to take some fake names for the demo'''
        '''They are going to be as small as number 5'''
        Lister=[{"ELE45786": {"id": "ELE45786", "Elector's_name": "Vinod", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE45693": {"id": "ELE45693", "Elector's_name": "Mani", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE45201": {"id": "ELE45201", "Elector's_name": "Ratnam", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE45101": {"id": "ELE45101", "Elector's_name": "John", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE45999":{"id": "ELE45999", "Elector's_name": "Alaadin", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE45789": {"id": "ELE45789", "Elector's_name": "Ram Ratna", "DOB": 1995, "voted": 0, "party": None}},
                     {"ELE46790": {"id": "ELE46790", "Elector's_name": "Teelu", "DOB": 1995, "voted": 0, "party": None}}]
        return Lister

# %%
voter_list()[voter_list().index({"ELE45786": {"id": "ELE45786", "Elector's_name": "Vinod", "DOB": 1995, "voted": 0, "party": None}})]['ELE45786']
# Out:
# {'id': 'ELE45786',
#  "Elector's_name": 'Vinod',
#  'DOB': 1995,
#  'voted': 0,
#  'party': None}

# %%
voter_list()
# Out:
# [{'ELE45786': {'id': 'ELE45786',
#    "Elector's_name": 'Vinod',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE45693': {'id': 'ELE45693',
#    "Elector's_name": 'Mani',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE45201': {'id': 'ELE45201',
#    "Elector's_name": 'Ratnam',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE45101': {'id': 'ELE45101',
#    "Elector's_name": 'John',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE45999': {'id': 'ELE45999',
#    "Elector's_name": 'Alaadin',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE45789': {'id': 'ELE45789',
#    "Elector's_name": 'Ram Ratna',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}},
#  {'ELE46790': {'id': 'ELE46790',
#    "Elector's_name": 'Teelu',
#    'DOB': 1995,
#    'voted': 0,
#    'party': None}}]

# %%
k={'ELE45786': {'id': 'ELE45786',
   "Elector's_name": 'Vinod',
   'DOB': 1995,
   'voted': 0,
   'party': None}}

# %%
k['ELE45786']['party']="l"

# %%
k={'ELE45786': {'id': 'ELE45786', "Elector's_name": 'Vinod', 'DOB': 1995, 'voted': 0, 'party': None}, 'ELE45693': {'id': 'ELE45693', "Elector's_name": 'Mani', 'DOB': 1995, 'voted': 0, 'party': None}, 'ELE45201': {'id': 'ELE45201', "Elector's_name": 'Ratnam', 'DOB': 1995, 'voted': 0, 'party': None}, 'ELE45101': {'id': 'ELE45101', "Elector's_name": 'John', 'DOB': 1995, 'voted': 0, 'party': None}, 'ELE45999': {'id': 'ELE45999', "Elector's_name": 'Alaadin', 'DOB': 1995, 'voted': 0, 'party': None}, 'ELE45789': {'id': 'ELE45789', "Elector's_name": 'Ram Ratna', 'DOB': 1995, 'voted': 0, 'party': None}, 'ELE46790': {'id': 'ELE46790', "Elector's_name": 'Teelu', 'DOB': 1995, 'voted': 0, 'party': None}}

# %%
k['ELE45786']
# Out:
# {'id': 'ELE45786',
#  "Elector's_name": 'Vinod',
#  'DOB': 1995,
#  'voted': 0,
#  'party': None}
